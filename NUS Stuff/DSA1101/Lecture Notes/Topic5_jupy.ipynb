# %%
import os
datadir = "C:\\Users\\Keck\\Documents\\GitHub\\devcontainers-rstudio\\NUS Stuff\\DSA1101\\Data"
os.chdir(datadir)
# print(os.getcwd())

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plot
# print(X)
# print(y)

dtree = DecisionTreeClassifier()
# dtree = dtree.fit(X, y)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

bank_data = pd.read_csv("bank-sample.csv") 
# print(bank_data)
bank_data = pd.get_dummies(bank_data)
# print(bank_data.head())

featmap = {k:v for v, k in enumerate(list(bank_data.columns))}
print(featmap)
X = bank_data.iloc[:,:-2]
y = bank_data.iloc[:, bank_data.columns == "subscribed_yes"]
#print(X.head())
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree)
# Out:
# {'age': 0, 'balance': 1, 'day': 2, 'duration': 3, 'campaign': 4, 'pdays': 5, 'previous': 6, 'job_admin.': 7, 'job_blue-collar': 8, 'job_entrepreneur': 9, 'job_housemaid': 10, 'job_management': 11, 'job_retired': 12, 'job_self-employed': 13, 'job_services': 14, 'job_student': 15, 'job_technician': 16, 'job_unemployed': 17, 'job_unknown': 18, 'marital_divorced': 19, 'marital_married': 20, 'marital_single': 21, 'education_primary': 22, 'education_secondary': 23, 'education_tertiary': 24, 'education_unknown': 25, 'default_no': 26, 'default_yes': 27, 'housing_no': 28, 'housing_yes': 29, 'loan_no': 30, 'loan_yes': 31, 'contact_cellular': 32, 'contact_telephone': 33, 'contact_unknown': 34, 'month_apr': 35, 'month_aug': 36, 'month_dec': 37, 'month_feb': 38, 'month_jan': 39, 'month_jul': 40, 'month_jun': 41, 'month_mar': 42, 'month_may': 43, 'month_nov': 44, 'month_oct': 45, 'month_sep': 46, 'poutcome_failure': 47, 'poutcome_other': 48, 'poutcome_success': 49, 'poutcome_unknown': 50, 'subscri
# ...
